# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()

# %%
# %matplotlib inline

# %%
AAPL = pd.read_csv('AAPL.csv')
MSFT = pd.read_csv('MSFT.csv')
MMM = pd.read_csv('MMM.csv')
AMZN = pd.read_csv('AMZN.csv')
GOOG = pd.read_csv('GOOG.csv')
JPM = pd.read_csv('JPM.csv')
BBT = pd.read_csv('BBT.csv')
SP = pd.read_csv('^GSPC.csv')

# %%
prices_AAPL = list(AAPL['Close'])[-506:]
prices_MSFT = list(MSFT['Close'])[-506:]
prices_MMM = list(MMM['Close'])[-506:]
prices_AMZN = list(AMZN['Close'])[-506:]
prices_GOOG = list(GOOG['Close'])[-506:]
prices_JPM = list(JPM['Close'])[-506:]
prices_BBT = list(BBT['Close'])[-506:]
prices_SP = list(SP['Close'])[-506:]

# %%
all_stock = pd.DataFrame({'AAPL': prices_AAPL,'MSFT': prices_MSFT,'MMM': prices_MMM
                          ,'AMZN': prices_AMZN,'GOOG': prices_GOOG,'JPM': prices_JPM,'BBT': prices_BBT , 'S&P500': prices_SP})

# %%
all_stock.head()
# Out:
#          AAPL       MSFT         MMM         AMZN         GOOG         JPM  \
# 0  163.050003  83.809998  234.740005  1100.949951  1019.270020  101.769997
# 1  166.720001  83.889999  231.020004  1110.849976  1017.109985  101.410004
# 2  169.039993  83.180000  230.190002  1105.280029  1016.640015  100.610001
# 3  166.889999  83.180000  230.179993  1103.680054  1025.500000  100.919998
# 4  168.110001  84.050003  232.229996  1094.219971  1025.579956  101.589996
#
#          BBT       S&P500
# 0  48.740002  2581.070068
# 1  49.110001  2572.830078
# 2  49.240002  2575.260010
# 3  49.549999  2579.360107
# 4  49.590000  2579.850098

# %%
all_stock.describe()
# Out:
#              AAPL        MSFT         MMM         AMZN         GOOG  \
# count  506.000000  506.000000  506.000000   506.000000   506.000000
# mean   190.578320  110.119051  200.798577  1661.248459  1126.911440
# std     21.789235   17.534236   24.667028   232.957964    71.618602
# min    142.190002   81.080002  150.740005  1094.219971   976.219971
# 25%    173.087505   95.882500  183.217495  1540.577515  1068.475006
# 50%    188.149994  107.564999  201.750000  1700.625000  1121.715027
# 75%    207.354999  125.485000  215.492504  1831.634979  1185.277527
# max    249.050003  144.610001  258.630005  2039.510010  1290.000000
#
#               JPM         BBT       S&P500
# count  506.000000  506.000000   506.000000
# mean   109.740791   50.449605  2786.832865
# std      5.849589    2.739868   130.695444
# min     92.139999   41.270000  2351.100098
# 25%    105.660002   48.790001  2690.302429
# 50%    109.959999   50.555001  2785.189941
# 75%    114.287500   52.305001  2888.770020
# ...

# %%
all_stock
# Out:
#            AAPL        MSFT         MMM         AMZN         GOOG         JPM  \
# 0    163.050003   83.809998  234.740005  1100.949951  1019.270020  101.769997
# 1    166.720001   83.889999  231.020004  1110.849976  1017.109985  101.410004
# 2    169.039993   83.180000  230.190002  1105.280029  1016.640015  100.610001
# 3    166.889999   83.180000  230.179993  1103.680054  1025.500000  100.919998
# 4    168.110001   84.050003  232.229996  1094.219971  1025.579956  101.589996
# ..          ...         ...         ...          ...          ...         ...
# 501  246.580002  140.729996  166.089996  1761.329956  1265.130005  126.029999
# 502  249.050003  144.190002  169.059998  1777.079956  1290.000000  126.510002
# 503  243.289993  142.830002  168.809998  1762.709961  1262.619995  126.430000
# 504  243.259995  144.610001  168.369995  1779.989990  1261.290039  125.730003
# 505  248.759995  143.369995  164.990005  1776.660034  1260.109985  124.919998
#
#            BBT       S&P500
# ...

# %%
import pandas as pd
AAPL = pd.read_csv('AAPL.csv') 
AAPL_profit = []
AAPL_profit.append(0)
base_day = -506
for i in range(506):
    current = int(i + -506)
    AAPL_profit.append((AAPL.iloc[current].Close/AAPL.iloc[base_day].Close) - 1)
    
MSFT = pd.read_csv('MSFT.csv') 
MSFT_profit = []
MSFT_profit.append(0)
base_day = -506
for i in range(506):
    current = int(i + -506)
    MSFT_profit.append((MSFT.iloc[current].Close/MSFT.iloc[base_day].Close) - 1)
    
MMM = pd.read_csv('MMM.csv') 
MMM_profit = []
MMM_profit.append(0)
base_day = -506
for i in range(506):
    current = int(i + -506)
    MMM_profit.append((MMM.iloc[current].Close/MMM.iloc[base_day].Close) - 1)
    
AMZN = pd.read_csv('AMZN.csv') 
AMZN_profit = []
AMZN_profit.append(0)
base_day = -506
for i in range(506):
    current = int(i + -506)
    AMZN_profit.append((AMZN.iloc[current].Close/AMZN.iloc[base_day].Close) - 1)
    
GOOG = pd.read_csv('GOOG.csv') 
GOOG_profit = []
GOOG_profit.append(0)
base_day = -506
for i in range(506):
    current = int(i + -506)
    GOOG_profit.append((GOOG.iloc[current].Close/GOOG.iloc[base_day].Close) - 1)
    
JPM = pd.read_csv('JPM.csv') 
JPM_profit = []
JPM_profit.append(0)
base_day = -506
for i in range(506):
    current = int(i + -506)
    JPM_profit.append((JPM.iloc[current].Close/JPM.iloc[base_day].Close) - 1)
    
BBT = pd.read_csv('BBT.csv') 
BBT_profit = []
BBT_profit.append(0)
base_day = -506
for i in range(506):
    current = int(i + -506)
    BBT_profit.append((BBT.iloc[current].Close/BBT.iloc[base_day].Close) - 1)
    
S_P_500 = pd.read_csv('^GSPC.csv') 
S_P_500_profits = []
S_P_500_profits.append(0)
base_day = -506
for i in range(506):
    current = int(i + -506)
    S_P_500_profits.append((S_P_500.iloc[current].Close/S_P_500.iloc[base_day].Close) - 1)

# %%
plt.figure(figsize=(15,6))
plt.plot(AAPL_profit)
plt.plot(MSFT_profit)
plt.plot(MMM_profit)
plt.plot(AMZN_profit)
plt.plot(GOOG_profit)
plt.plot(JPM_profit)
plt.plot(BBT_profit)
plt.plot(S_P_500_profits)
plt.legend(['AAPL', 'MSFT', 'MMM', 'AMZN', 'GOOG', 'JPM', 'BBT', 'S&P'])
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001EF4A781AF8> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     303                                              cwd=self.texcache,
# --> 304                                              stderr=subprocess.STDOUT)
#     305         except FileNotFoundError as exc:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     471
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.style.use('seaborn-white')
plt.rc('font', family='serif', serif='Times')
plt.rc('pdf', fonttype=42)
plt.rc('text', usetex=True)
mpl.use('pdf')
# %matplotlib inline

plt.plot(x, x, '-', color='red')
plt.plot(observed_quantiles, theorical_quantiles, '.', color='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-775885f0c957> in <module>
#      10
#      11 plt.plot(x, x, '-', color='red')
# ---> 12 plt.plot(observed_quantiles, theorical_quantiles, '.', color='black')
#      13 plt.show()
#
# NameError: name 'observed_quantiles' is not defined
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001EF4A781AF8> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     303                                              cwd=self.texcache,
# --> 304                                              stderr=subprocess.STDOUT)
# ...
